# %%
import yfinance as yf
from datetime import datetime, timedelta

# %%
start_day = datetime.datetime.strptime("2020-01-01", "%Y-%m-%d")
end_day = datetime.datetime.strptime("2020-05-06", "%Y-%m-%d")
interval = 20
print(start_day)
print(end_day)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cd95c87c3332> in <module>
# ----> 1 start_day = datetime.datetime.strptime("2020-01-01", "%Y-%m-%d")
#       2 end_day = datetime.datetime.strptime("2000-05-06", "%Y-%m-%d")
#       3 interval = 20
#       4 print(start_day)
#       5 print(end_day)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
ticker_df = yf.Ticker("MSFT").history(start=start_day-datetime.timedelta(days=1), end=start_day+datetime.timedelta(days=2))
ticker_df
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2000-01-31  31.074686  31.253733  30.199343  31.154263  73194200          0
# 2000-02-01  31.353219  32.865176  31.094594  32.765705  70196600          0
# 2000-02-02  32.606539  33.083999  31.989820  32.089291  49915600          0
#
#             Stock Splits
# Date
# 2000-01-31             0
# 2000-02-01             0
# 2000-02-02             0

# %%
new_day = start_day
amounts = []
while (new_day < end_day):
    amount = value / ticker_df[ticker_df.index == new_date][["Open", "High", "Low", "Close"]].mean().mean()
    amounts.append(amount)

print(amounts)

# %%
ticker_df[ticker_df.index == start_day.strftime("%Y-%m-%d")][["Open", "High", "Low", "Close"]].mean().mean()
# Out:
# 32.019673571560546

# %%
ticker_df[ticker_df.index == "2000-02-01"][["Open", "High", "Low", "Close"]].mean().mean()
# Out:
# 32.019673571560546

# %%
date = start_day
ticker_df[ticker_df["Date"] == date.strftime("%Y-%m-%d")][["Open","High", "Low", "Close"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f1d252cdc979> in <module>
#       1 date = start_day
# ----> 2 ticker_df[ticker_df["Date"] == date.strftime("%Y-%m-%d")][["Open","High", "Low", "Close"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Date'
